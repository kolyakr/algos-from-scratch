# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("./countries_economic_clusters.csv")
data = data.set_index("країна")
data
# Out:
#            ВВП_на_душу_населення_тис$*  рівень_безробіття*%  індекс_освіти  \
# країна
# США                                 68                  4.5           0.92
# Німеччина                           60                  3.5           0.93
# Італія                              55                  4.0           0.94
# Японія                              50                  2.8           0.91
# Франція                             45                  7.0           0.90
# Польща                              18                  5.5           0.85
# Угорщина                            16                  6.0           0.83
# Румунія                             15                  5.0           0.80
# Індія                                7                  7.5           0.65
# Нігерія                              6                  7.0           0.55
# Пакистан                             5                  6.5           0.50
# Ефіопія                              3                 12.0           0.45
#
#            тривалість_життя  індекс_щастя
# країна
# США                      79           7.0
# Німеччина                81           7.2
# Італія                   82           7.5
# Японія                   84           6.9
# Франція                  82           6.8
# Польща                   77           6.0
# Угорщина                 76           5.8
# Румунія                  75           5.7
# Індія                    70           4.0
# Нігерія                  66           4.1
# Пакистан                 65           3.8
# Ефіопія                  63           3.5

# %%
#chosen metric for distance - Euclidian distance

def euclidian_distance(x1: np.ndarray, x2: np.ndarray):
  return np.sqrt(np.sum([(x2_i - x1_i)**2 for x1_i, x2_i in zip(x1, x2)]))

# %%
def get_cluster_len(cluster: tuple):
  counter = 0
  for element in cluster:
    if pd.isna(element):
      continue
    
    counter += 1
      
  return counter

# %%
def compute_distance_matrix(data, clusters):
  distance_matrix = pd.DataFrame(columns=pd.Index(clusters),
                                 index=pd.Index(clusters),
                                 data=np.zeros((len(clusters), len(clusters))))
  
  for row in distance_matrix.index:
    for column in distance_matrix.columns:
      if row == column:
        continue
      
      if get_cluster_len(row) > 1 and get_cluster_len(column) <= 1:
        distances = []
        for idx in range(get_cluster_len(row)):
          distances.append(
            euclidian_distance(np.array(data.loc[row[idx]]), 
                               np.array(data.loc[column[0]]))
          )
        distance_matrix.loc[row, column] = min(distances)
        continue
        
      if get_cluster_len(column) > 1 and get_cluster_len(row) <= 1:
        distances = []
        for idx in range(get_cluster_len(column)):
          distances.append(
            euclidian_distance(np.array(data.loc[row[0]]), 
                               np.array(data.loc[column[idx]]))
          )
        distance_matrix.loc[row, column] = min(distances)
        continue
      
      if get_cluster_len(column) > 1 and get_cluster_len(row) > 1:
        distances = []
        for row_idx in range(get_cluster_len(row)):
          for col_idx in range(get_cluster_len(column)):
            distances.append(
              euclidian_distance(np.array(data.loc[row[row_idx]]),
                                 np.array(data.loc[column[col_idx]]))
            )
        distance_matrix.loc[row, column] = min(distances)
        continue
      
      distance_matrix.loc[row, column] = euclidian_distance(
        np.array(data.loc[row[0]]), 
        np.array(data.loc[column[0]])
      )
  
  return distance_matrix

# %%
def find_min_distance(distance_matrix):
  min_distance = 10**10
  min_label_1 = None
  min_label_2 = None

  for row in distance_matrix.index:
    new_row = distance_matrix.loc[row].drop(row)
    minima = new_row.min()
    
    if minima > min_distance:
      continue
    
    min_distance = minima
    min_label_1 = row
    min_label_2 = new_row.idxmin()
  
  return (min_distance, [min_label_1, min_label_2])

# %%
def clean_labels(labels):
    cleaned_labels = []
    for label in labels:
        cleaned = tuple(x for x in label if not pd.isna(x))
        cleaned_labels.append(cleaned)
    return cleaned_labels

# %%
def delete_and_create_clusters(clusters, labels):
    cleaned_labels = clean_labels(labels)

    for label in cleaned_labels:
        if pd.isna(label):
            continue
        if label in clusters:
            clusters.remove(label)

    values = []
    for cluster in cleaned_labels:
        for element in cluster:
            if not pd.isna(element):
                values.append(element)

    clusters.append(tuple(values))
    return clusters

# %%
def clustering(data):
    clusters = [(index,) for index in data.index]
    clusters_history = []
    iter = 0

    while len(clusters) > 1:
        iter += 1
        print("=" * 60)
        print(f"ITERATION {iter}")
        print("=" * 60)
        
        print("\nCurrent Clusters:")
        for i, c in enumerate(clusters):
            print(f"  {i+1:>2}. {c}")

        # Compute distance matrix
        distance_matrix = compute_distance_matrix(data, clusters)
        
        print("\nDistance Matrix:")
        with pd.option_context('display.max_rows', None, 'display.max_columns', None):
            print(distance_matrix.round(3))

        # Find minimum distance
        min_distance, labels = find_min_distance(distance_matrix)
        print(f"\nMinimum Distance: {min_distance:.4f}")
        print(f"Clusters to Merge: {labels}")

        # Update clusters
        clusters = delete_and_create_clusters(clusters, labels)
        clusters_history.append(clusters)

        print("\nUpdated Clusters:")
        for i, c in enumerate(clusters):
            print(f"  {i+1:>2}. {c}")
        print("\n")

    print("=" * 60)
    print("Final Clusters:")
    for i, c in enumerate(clusters):
        print(f"  {i+1:>2}. {c}")
    print("=" * 60)

    return clusters_history

# %%
history = clustering(data)
# Out:
# ============================================================
# ITERATION 1
# ============================================================
#
# Current Clusters:
#    1. ('США',)
#    2. ('Німеччина',)
#    3. ('Італія',)
#    4. ('Японія',)
#    5. ('Франція',)
#    6. ('Польща',)
#    7. ('Угорщина',)
#    8. ('Румунія',)
#    9. ('Індія',)
#   10. ('Нігерія',)
#   11. ('Пакистан',)
#   12. ('Ефіопія',)
#
# Distance Matrix:
#               США Німеччина  Італія  Японія Франція  Польща Угорщина Румунія  \
# США         0.000     8.309  13.360  18.759  23.330  50.060   52.122  53.169
# Німеччина   8.309     0.000   5.132  10.468  15.441  42.255   44.376  45.448
# Італія     13.360     5.132   0.000   5.550  10.464  37.397   39.546  40.660
# Японія     18.759    10.468   5.550   0.000   6.830  32.880   35.092  36.226
# Франція    23.330    15.441  10.464   6.830   0.000  27.512   29.648  30.890
# Польща     50.060    42.255  37.397  32.880  27.512   0.000    2.300   3.653
# Угорщина   52.122    44.376  39.546  35.092  29.648   2.300    0.000   1.735
# Румунія    53.169    45.448  40.660  36.226  30.890   3.653    1.735   0.000
# Індія      61.807    54.372  49.725  45.558  39.952  13.343   11.069   9.908
# Нігерія    63.465    56.241  51.747  47.808  42.242  16.461   14.282  12.985
# Пакистан   64.648    57.461  53.001  49.086  43.571  17.860   15.696  14.351
# Ефіопія    67.452    60.491  56.082  52.406  46.488  21.672   19.479  18.492
#
#             Індія Нігерія Пакистан Ефіопія
# США        61.807  63.465   64.648  67.452
# Німеччина  54.372  56.241   57.461  60.491
# Італія     49.725  51.747   53.001  56.082
# Японія     45.558  47.808   49.086  52.406
# Франція    39.952  42.242   43.571  46.488
# Польща     13.343  16.461   17.860  21.672
# Угорщина   11.069  14.282   15.696  19.479
# Румунія     9.908  12.985   14.351  18.492
# Індія       0.000   4.156    5.483   9.249
# Нігерія     4.156   0.000    1.531   6.586
# Пакистан    5.483   1.531    0.000   6.192
# Ефіопія     9.249   6.586    6.192   0.000
#
# Minimum Distance: 1.5305
# Clusters to Merge: [('Пакистан',), ('Нігерія',)]
#
# Updated Clusters:
#    1. ('США',)
#    2. ('Німеччина',)
#    3. ('Італія',)
#    4. ('Японія',)
#    5. ('Франція',)
#    6. ('Польща',)
#    7. ('Угорщина',)
#    8. ('Румунія',)
#    9. ('Індія',)
#   10. ('Ефіопія',)
#   11. ('Пакистан', 'Нігерія')
#
#
# ============================================================
# ITERATION 2
# ============================================================
#
# Current Clusters:
#    1. ('США',)
#    2. ('Німеччина',)
#    3. ('Італія',)
#    4. ('Японія',)
#    5. ('Франція',)
#    6. ('Польща',)
#    7. ('Угорщина',)
#    8. ('Румунія',)
#    9. ('Індія',)
#   10. ('Ефіопія',)
#   11. ('Пакистан', 'Нігерія')
#
# Distance Matrix:
#                       США Німеччина  Італія  Японія Франція  Польща Угорщина  \
#                       NaN       NaN     NaN     NaN     NaN     NaN      NaN
# США       NaN       0.000     8.309  13.360  18.759  23.330  50.060   52.122
# Німеччина NaN       8.309     0.000   5.132  10.468  15.441  42.255   44.376
# Італія    NaN      13.360     5.132   0.000   5.550  10.464  37.397   39.546
# Японія    NaN      18.759    10.468   5.550   0.000   6.830  32.880   35.092
# Франція   NaN      23.330    15.441  10.464   6.830   0.000  27.512   29.648
# Польща    NaN      50.060    42.255  37.397  32.880  27.512   0.000    2.300
# Угорщина  NaN      52.122    44.376  39.546  35.092  29.648   2.300    0.000
# Румунія   NaN      53.169    45.448  40.660  36.226  30.890   3.653    1.735
# Індія     NaN      61.807    54.372  49.725  45.558  39.952  13.343   11.069
# Ефіопія   NaN      67.452    60.491  56.082  52.406  46.488  21.672   19.479
# Пакистан  Нігерія  63.465    56.241  51.747  47.808  42.242  16.461   14.282
#
#                   Румунія   Індія Ефіопія Пакистан
#                       NaN     NaN     NaN  Нігерія
# США       NaN      53.169  61.807  67.452   63.465
# Німеччина NaN      45.448  54.372  60.491   56.241
# Італія    NaN      40.660  49.725  56.082   51.747
# Японія    NaN      36.226  45.558  52.406   47.808
# Франція   NaN      30.890  39.952  46.488   42.242
# Польща    NaN       3.653  13.343  21.672   16.461
# Угорщина  NaN       1.735  11.069  19.479   14.282
# Румунія   NaN       0.000   9.908  18.492   12.985
# Індія     NaN       9.908   0.000   9.249    4.156
# Ефіопія   NaN      18.492   9.249   0.000    6.192
# Пакистан  Нігерія  12.985   4.156   6.192    0.000
#
# Minimum Distance: 1.7352
# Clusters to Merge: [('Румунія', nan), ('Угорщина', nan)]
#
# Updated Clusters:
#    1. ('США',)
#    2. ('Німеччина',)
#    3. ('Італія',)
#    4. ('Японія',)
#    5. ('Франція',)
#    6. ('Польща',)
#    7. ('Індія',)
#    8. ('Ефіопія',)
#    9. ('Пакистан', 'Нігерія')
#   10. ('Румунія', 'Угорщина')
#
#
# ============================================================
# ITERATION 3
# ============================================================
#
# Current Clusters:
#    1. ('США',)
#    2. ('Німеччина',)
#    3. ('Італія',)
#    4. ('Японія',)
#    5. ('Франція',)
#    6. ('Польща',)
#    7. ('Індія',)
#    8. ('Ефіопія',)
#    9. ('Пакистан', 'Нігерія')
#   10. ('Румунія', 'Угорщина')
#
# Distance Matrix:
#                        США Німеччина  Італія  Японія Франція  Польща   Індія  \
#                        NaN       NaN     NaN     NaN     NaN     NaN     NaN
# США       NaN        0.000     8.309  13.360  18.759  23.330  50.060  61.807
# Німеччина NaN        8.309     0.000   5.132  10.468  15.441  42.255  54.372
# Італія    NaN       13.360     5.132   0.000   5.550  10.464  37.397  49.725
# Японія    NaN       18.759    10.468   5.550   0.000   6.830  32.880  45.558
# Франція   NaN       23.330    15.441  10.464   6.830   0.000  27.512  39.952
# Польща    NaN       50.060    42.255  37.397  32.880  27.512   0.000  13.343
# Індія     NaN       61.807    54.372  49.725  45.558  39.952  13.343   0.000
# Ефіопія   NaN       67.452    60.491  56.082  52.406  46.488  21.672   9.249
# Пакистан  Нігерія   63.465    56.241  51.747  47.808  42.242  16.461   4.156
# Румунія   Угорщина  52.122    44.376  39.546  35.092  29.648   2.300   9.908
#
#                    Ефіопія Пакистан  Румунія
#                        NaN  Нігерія Угорщина
# США       NaN       67.452   63.465   52.122
# Німеччина NaN       60.491   56.241   44.376
# Італія    NaN       56.082   51.747   39.546
# Японія    NaN       52.406   47.808   35.092
# Франція   NaN       46.488   42.242   29.648
# Польща    NaN       21.672   16.461    2.300
# Індія     NaN        9.249    4.156    9.908
# Ефіопія   NaN        0.000    6.192   18.492
# Пакистан  Нігерія    6.192    0.000   12.985
# Румунія   Угорщина  18.492   12.985    0.000
#
# Minimum Distance: 2.3001
# Clusters to Merge: [('Румунія', 'Угорщина'), ('Польща', nan)]
#
# Updated Clusters:
#    1. ('США',)
#    2. ('Німеччина',)
#    3. ('Італія',)
#    4. ('Японія',)
#    5. ('Франція',)
#    6. ('Індія',)
#    7. ('Ефіопія',)
#    8. ('Пакистан', 'Нігерія')
#    9. ('Румунія', 'Угорщина', 'Польща')
#
#
# ============================================================
# ITERATION 4
# ============================================================
#
# Current Clusters:
#    1. ('США',)
#    2. ('Німеччина',)
#    3. ('Італія',)
#    4. ('Японія',)
#    5. ('Франція',)
#    6. ('Індія',)
#    7. ('Ефіопія',)
#    8. ('Пакистан', 'Нігерія')
#    9. ('Румунія', 'Угорщина', 'Польща')
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:42: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = euclidian_distance(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:28: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:39: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:42: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = euclidian_distance(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:28: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:39: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:42: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = euclidian_distance(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:28: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:39: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:42: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = euclidian_distance(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:28: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:39: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:42: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = euclidian_distance(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:28: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:39: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:28: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:18: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:39: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
# Distance Matrix:
#                               США Німеччина  Італія  Японія Франція   Індія  \
#                               NaN       NaN     NaN     NaN     NaN     NaN
#                               NaN       NaN     NaN     NaN     NaN     NaN
# США       NaN      NaN      0.000     8.309  13.360  18.759  23.330  61.807
# Німеччина NaN      NaN      8.309     0.000   5.132  10.468  15.441  54.372
# Італія    NaN      NaN     13.360     5.132   0.000   5.550  10.464  49.725
# Японія    NaN      NaN     18.759    10.468   5.550   0.000   6.830  45.558
# Франція   NaN      NaN     23.330    15.441  10.464   6.830   0.000  39.952
# Індія     NaN      NaN     61.807    54.372  49.725  45.558  39.952   0.000
# Ефіопія   NaN      NaN     67.452    60.491  56.082  52.406  46.488   9.249
# Пакистан  Нігерія  NaN     63.465    56.241  51.747  47.808  42.242   4.156
# Румунія   Угорщина Польща  50.060    42.255  37.397  32.880  27.512   9.908
#
#                           Ефіопія Пакистан  Румунія
#                               NaN  Нігерія Угорщина
#                               NaN      NaN   Польща
# США       NaN      NaN     67.452   63.465   50.060
# Німеччина NaN      NaN     60.491   56.241   42.255
# Італія    NaN      NaN     56.082   51.747   37.397
# Японія    NaN      NaN     52.406   47.808   32.880
# Франція   NaN      NaN     46.488   42.242   27.512
# Індія     NaN      NaN      9.249    4.156    9.908
# Ефіопія   NaN      NaN      0.000    6.192   18.492
# Пакистан  Нігерія  NaN      6.192    0.000   12.985
# Румунія   Угорщина Польща  18.492   12.985    0.000
#
# Minimum Distance: 4.1557
# Clusters to Merge: [('Пакистан', 'Нігерія', nan), ('Індія', nan, nan)]
#
# Updated Clusters:
#    1. ('США',)
#    2. ('Німеччина',)
#    3. ('Італія',)
#    4. ('Японія',)
#    5. ('Франція',)
#    6. ('Ефіопія',)
#    7. ('Румунія', 'Угорщина', 'Польща')
#    8. ('Пакистан', 'Нігерія', 'Індія')
#
#
# ============================================================
# ITERATION 5
# ============================================================
#
# Current Clusters:
#    1. ('США',)
#    2. ('Німеччина',)
#    3. ('Італія',)
#    4. ('Японія',)
#    5. ('Франція',)
#    6. ('Ефіопія',)
#    7. ('Румунія', 'Угорщина', 'Польща')
#    8. ('Пакистан', 'Нігерія', 'Індія')
#
# Distance Matrix:
#                               США Німеччина  Італія  Японія Франція Ефіопія  \
#                               NaN       NaN     NaN     NaN     NaN     NaN
#                               NaN       NaN     NaN     NaN     NaN     NaN
# США       NaN      NaN      0.000     8.309  13.360  18.759  23.330  67.452
# Німеччина NaN      NaN      8.309     0.000   5.132  10.468  15.441  60.491
# Італія    NaN      NaN     13.360     5.132   0.000   5.550  10.464  56.082
# Японія    NaN      NaN     18.759    10.468   5.550   0.000   6.830  52.406
# Франція   NaN      NaN     23.330    15.441  10.464   6.830   0.000  46.488
# Ефіопія   NaN      NaN     67.452    60.491  56.082  52.406  46.488   0.000
# Румунія   Угорщина Польща  50.060    42.255  37.397  32.880  27.512  18.492
# Пакистан  Нігерія  Індія   61.807    54.372  49.725  45.558  39.952   6.192
#
#                            Румунія Пакистан
#                           Угорщина  Нігерія
#                             Польща    Індія
# США       NaN      NaN      50.060   61.807
# Німеччина NaN      NaN      42.255   54.372
# Італія    NaN      NaN      37.397   49.725
# Японія    NaN      NaN      32.880   45.558
# Франція   NaN      NaN      27.512   39.952
# Ефіопія   NaN      NaN      18.492    6.192
# Румунія   Угорщина Польща    0.000    9.908
# Пакистан  Нігерія  Індія     9.908    0.000
#
# Minimum Distance: 5.1323
# Clusters to Merge: [('Італія', nan, nan), ('Німеччина', nan, nan)]
#
# Updated Clusters:
#    1. ('США',)
#    2. ('Японія',)
#    3. ('Франція',)
#    4. ('Ефіопія',)
#    5. ('Румунія', 'Угорщина', 'Польща')
#    6. ('Пакистан', 'Нігерія', 'Індія')
#    7. ('Італія', 'Німеччина')
#
#
# ============================================================
# ITERATION 6
# ============================================================
#
# Current Clusters:
#    1. ('США',)
#    2. ('Японія',)
#    3. ('Франція',)
#    4. ('Ефіопія',)
#    5. ('Румунія', 'Угорщина', 'Польща')
#    6. ('Пакистан', 'Нігерія', 'Індія')
#    7. ('Італія', 'Німеччина')
#
# Distance Matrix:
#                               США  Японія Франція Ефіопія  Румунія Пакистан  \
#                               NaN     NaN     NaN     NaN Угорщина  Нігерія
#                               NaN     NaN     NaN     NaN   Польща    Індія
# США      NaN       NaN      0.000  18.759  23.330  67.452   50.060   61.807
# Японія   NaN       NaN     18.759   0.000   6.830  52.406   32.880   45.558
# Франція  NaN       NaN     23.330   6.830   0.000  46.488   27.512   39.952
# Ефіопія  NaN       NaN     67.452  52.406  46.488   0.000   18.492    6.192
# Румунія  Угорщина  Польща  50.060  32.880  27.512  18.492    0.000    9.908
# Пакистан Нігерія   Індія   61.807  45.558  39.952   6.192    9.908    0.000
# Італія   Німеччина NaN      8.309   5.550  10.464  56.082   37.397   49.725
#
#                              Італія
#                           Німеччина
#                                 NaN
# США      NaN       NaN        8.309
# Японія   NaN       NaN        5.550
# Франція  NaN       NaN       10.464
# Ефіопія  NaN       NaN       56.082
# Румунія  Угорщина  Польща    37.397
# Пакистан Нігерія   Індія     49.725
# Італія   Німеччина NaN        0.000
#
# Minimum Distance: 5.5499
# Clusters to Merge: [('Італія', 'Німеччина', nan), ('Японія', nan, nan)]
#
# Updated Clusters:
#    1. ('США',)
#    2. ('Франція',)
#    3. ('Ефіопія',)
#    4. ('Румунія', 'Угорщина', 'Польща')
#    5. ('Пакистан', 'Нігерія', 'Індія')
#    6. ('Італія', 'Німеччина', 'Японія')
#
#
# ============================================================
# ITERATION 7
# ============================================================
#
# Current Clusters:
#    1. ('США',)
#    2. ('Франція',)
#    3. ('Ефіопія',)
#    4. ('Румунія', 'Угорщина', 'Польща')
#    5. ('Пакистан', 'Нігерія', 'Індія')
#    6. ('Італія', 'Німеччина', 'Японія')
#
# Distance Matrix:
#                               США Франція Ефіопія  Румунія Пакистан    Італія
#                               NaN     NaN     NaN Угорщина  Нігерія Німеччина
#                               NaN     NaN     NaN   Польща    Індія    Японія
# США      NaN       NaN      0.000  23.330  67.452   50.060   61.807     8.309
# Франція  NaN       NaN     23.330   0.000  46.488   27.512   39.952     6.830
# Ефіопія  NaN       NaN     67.452  46.488   0.000   18.492    6.192    52.406
# Румунія  Угорщина  Польща  50.060  27.512  18.492    0.000    9.908    32.880
# Пакистан Нігерія   Індія   61.807  39.952   6.192    9.908    0.000    45.558
# Італія   Німеччина Японія   8.309   6.830  52.406   32.880   45.558     0.000
#
# Minimum Distance: 6.1921
# Clusters to Merge: [('Пакистан', 'Нігерія', 'Індія'), ('Ефіопія', nan, nan)]
#
# Updated Clusters:
#    1. ('США',)
#    2. ('Франція',)
#    3. ('Румунія', 'Угорщина', 'Польща')
#    4. ('Італія', 'Німеччина', 'Японія')
#    5. ('Пакистан', 'Нігерія', 'Індія', 'Ефіопія')
#
#
# ============================================================
# ITERATION 8
# ============================================================
#
# Current Clusters:
#    1. ('США',)
#    2. ('Франція',)
#    3. ('Румунія', 'Угорщина', 'Польща')
#    4. ('Італія', 'Німеччина', 'Японія')
#    5. ('Пакистан', 'Нігерія', 'Індія', 'Ефіопія')
#
# Distance Matrix:
#                                       США Франція  Румунія    Італія Пакистан
#                                       NaN     NaN Угорщина Німеччина  Нігерія
#                                       NaN     NaN   Польща    Японія    Індія
#                                       NaN     NaN      NaN       NaN  Ефіопія
# США      NaN       NaN    NaN       0.000  23.330   50.060     8.309   61.807
# Франція  NaN       NaN    NaN      23.330   0.000   27.512     6.830   39.952
# Румунія  Угорщина  Польща NaN      50.060  27.512    0.000    32.880    9.908
# Італія   Німеччина Японія NaN       8.309   6.830   32.880     0.000   45.558
# Пакистан Нігерія   Індія  Ефіопія  61.807  39.952    9.908    45.558    0.000
#
# Minimum Distance: 6.8301
# Clusters to Merge: [('Італія', 'Німеччина', 'Японія', nan), ('Франція', nan, nan, nan)]
#
# Updated Clusters:
#    1. ('США',)
#    2. ('Румунія', 'Угорщина', 'Польща')
#    3. ('Пакистан', 'Нігерія', 'Індія', 'Ефіопія')
#    4. ('Італія', 'Німеччина', 'Японія', 'Франція')
#
#
# ============================================================
# ITERATION 9
# ============================================================
#
# Current Clusters:
#    1. ('США',)
#    2. ('Румунія', 'Угорщина', 'Польща')
#    3. ('Пакистан', 'Нігерія', 'Індія', 'Ефіопія')
#    4. ('Італія', 'Німеччина', 'Японія', 'Франція')
#
# Distance Matrix:
#                                       США  Румунія Пакистан    Італія
#                                       NaN Угорщина  Нігерія Німеччина
#                                       NaN   Польща    Індія    Японія
#                                       NaN      NaN  Ефіопія   Франція
# США      NaN       NaN    NaN       0.000   50.060   61.807     8.309
# Румунія  Угорщина  Польща NaN      50.060    0.000    9.908    27.512
# Пакистан Нігерія   Індія  Ефіопія  61.807    9.908    0.000    39.952
# Італія   Німеччина Японія Франція   8.309   27.512   39.952     0.000
#
# Minimum Distance: 8.3090
# Clusters to Merge: [('Італія', 'Німеччина', 'Японія', 'Франція'), ('США', nan, nan, nan)]
#
# Updated Clusters:
#    1. ('Румунія', 'Угорщина', 'Польща')
#    2. ('Пакистан', 'Нігерія', 'Індія', 'Ефіопія')
#    3. ('Італія', 'Німеччина', 'Японія', 'Франція', 'США')
#
#
# ============================================================
# ITERATION 10
# ============================================================
#
# Current Clusters:
#    1. ('Румунія', 'Угорщина', 'Польща')
#    2. ('Пакистан', 'Нігерія', 'Індія', 'Ефіопія')
#    3. ('Італія', 'Німеччина', 'Японія', 'Франція', 'США')
#
# Distance Matrix:
#                                        Румунія Пакистан    Італія
#                                       Угорщина  Нігерія Німеччина
#                                         Польща    Індія    Японія
#                                            NaN  Ефіопія   Франція
#                                            NaN      NaN       США
# Румунія  Угорщина  Польща NaN     NaN    0.000    9.908    27.512
# Пакистан Нігерія   Індія  Ефіопія NaN    9.908    0.000    39.952
# Італія   Німеччина Японія Франція США   27.512   39.952     0.000
#
# Minimum Distance: 9.9077
# Clusters to Merge: [('Пакистан', 'Нігерія', 'Індія', 'Ефіопія', nan), ('Румунія', 'Угорщина', 'Польща', nan, nan)]
#
# Updated Clusters:
#    1. ('Італія', 'Німеччина', 'Японія', 'Франція', 'США')
#    2. ('Пакистан', 'Нігерія', 'Індія', 'Ефіопія', 'Румунія', 'Угорщина', 'Польща')
#
#
# ============================================================
# ITERATION 11
# ============================================================
#
# Current Clusters:
#    1. ('Італія', 'Німеччина', 'Японія', 'Франція', 'США')
#    2. ('Пакистан', 'Нігерія', 'Індія', 'Ефіопія', 'Румунія', 'Угорщина', 'Польща')
#
# Distance Matrix:
#                                                              Італія Пакистан
#                                                           Німеччина  Нігерія
#                                                              Японія    Індія
#                                                             Франція  Ефіопія
#                                                                 США  Румунія
#                                                                 NaN Угорщина
#                                                                 NaN   Польща
# Італія   Німеччина Японія Франція США     NaN      NaN        0.000   27.512
# Пакистан Нігерія   Індія  Ефіопія Румунія Угорщина Польща    27.512    0.000
#
# Minimum Distance: 27.5117
# Clusters to Merge: [('Пакистан', 'Нігерія', 'Індія', 'Ефіопія', 'Румунія', 'Угорщина', 'Польща'), ('Італія', 'Німеччина', 'Японія', 'Франція', 'США', nan, nan)]
#
# Updated Clusters:
#    1. ('Пакистан', 'Нігерія', 'Індія', 'Ефіопія', 'Румунія', 'Угорщина', 'Польща', 'Італія', 'Німеччина', 'Японія', 'Франція', 'США')
#
#
# ============================================================
# Final Clusters:
#    1. ('Пакистан', 'Нігерія', 'Індія', 'Ефіопія', 'Румунія', 'Угорщина', 'Польща', 'Італія', 'Німеччина', 'Японія', 'Франція', 'США')
# ============================================================
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7764\2944328450.py:39: PerformanceWarning: indexing past lexsort depth may impact performance.
#   distance_matrix.loc[row, column] = min(distances)
